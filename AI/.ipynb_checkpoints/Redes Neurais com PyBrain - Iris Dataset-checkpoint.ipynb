# %%
import numpy as np

# carregando os dados com numpy
entradas = np.genfromtxt('iris.data', delimiter=',', usecols=(0,1,2,3))
saidas = np.genfromtxt('iris.data', delimiter=',', usecols=(4))
print(len(entradas))
print(len(saidas))
# Out:
# 150
# 150

# %%
'''
Iris-setosa: 0
Iris-versicolor: 1
Iris-virginica: 2
'''

# mostrando as 5 primeiras amostras que são Iris-setosa
print(entradas[:5])
print(saidas[:5])

print('---------------------')

# mostrando as 5 últimas amostras que são de Iris-virginica
print(entradas[-5:])
print(saidas[-5:])
# Out:
# [[ 5.1  3.5  1.4  0.2]
#  [ 4.9  3.   1.4  0.2]
#  [ 4.7  3.2  1.3  0.2]
#  [ 4.6  3.1  1.5  0.2]
#  [ 5.   3.6  1.4  0.2]]
# [ 0.  0.  0.  0.  0.]
# ---------------------
# [[ 6.7  3.   5.2  2.3]
#  [ 6.3  2.5  5.   1.9]
#  [ 6.5  3.   5.2  2. ]
#  [ 6.2  3.4  5.4  2.3]
#  [ 5.9  3.   5.1  1.8]]
# [ 2.  2.  2.  2.  2.]

# %%
# vou utilizar 105 amostras para treino sendo 35 de cada classe
entradas_treino = np.concatenate((entradas[:35], entradas[50:85], entradas[100:135]))
saidas_treino = np.concatenate((saidas[:35], saidas[50:85], saidas[100:135]))
print(len(entradas_treino))
print(len(saidas_treino))
# Out:
# 105
# 105

# %%
entradas_teste = np.concatenate((entradas[35:50], entradas[85:100], entradas[135:]))
saidas_teste = np.concatenate((saidas[35:50], saidas[85:100], saidas[135:]))
print(len(entradas_teste))
print(len(saidas_teste))
# Out:
# 45
# 45

# %%
from pybrain.datasets import SupervisedDataSet
from pybrain.tools.shortcuts import buildNetwork
from pybrain.supervised import BackpropTrainer

# %%
treinamento = SupervisedDataSet(4, 1)
for i in range(len(entradas_treino)):
    treinamento.addSample(entradas_treino[i], saidas_treino[i])
print(len(treinamento))
print(treinamento.indim)
print(treinamento.outdim)
# Out:
# 105
# 4
# 1

# %%
# construindo a rede
rede = buildNetwork(treinamento.indim, 2, treinamento.outdim, bias=True)
trainer = BackpropTrainer(rede, treinamento, learningrate=0.01, momentum=0.3)

# treinando a rede
for epoca in range(1000):
    trainer.train()
    
# testando a rede
teste = SupervisedDataSet(4, 1)
for i in range(len(entradas_teste)):
    teste.addSample(entradas_teste[i], saidas_teste[i])
trainer.testOnData(teste, verbose=True)
# Out:
# Testing on data:
# ('out:    ', '[0.018 ]')
# ('correct:', '[0     ]')
# error:  0.00016277
# ('out:    ', '[0.012 ]')
# ('correct:', '[0     ]')
# error:  0.00007168
# ('out:    ', '[0.029 ]')
# ('correct:', '[0     ]')
# error:  0.00041728
# ('out:    ', '[0.034 ]')
# ('correct:', '[0     ]')
# error:  0.00058792
# ('out:    ', '[0.023 ]')
# ('correct:', '[0     ]')
# error:  0.00026161
# ('out:    ', '[0.019 ]')
# ('correct:', '[0     ]')
# error:  0.00017190
# ('out:    ', '[0.059 ]')
# ('correct:', '[0     ]')
# error:  0.00171173
# ('out:    ', '[0.03  ]')
# ('correct:', '[0     ]')
# error:  0.00043935
# ('out:    ', '[0.039 ]')
# ('correct:', '[0     ]')
# error:  0.00077005
# ('out:    ', '[0.037 ]')
# ('correct:', '[0     ]')
# error:  0.00068674
# ('out:    ', '[0.035 ]')
# ('correct:', '[0     ]')
# error:  0.00061468
# ('out:    ', '[0.019 ]')
# ('correct:', '[0     ]')
# error:  0.00018938
# ('out:    ', '[0.031 ]')
# ('correct:', '[0     ]')
# error:  0.00046668
# ('out:    ', '[0.016 ]')
# ('correct:', '[0     ]')
# error:  0.00012761
# ('out:    ', '[0.023 ]')
# ('correct:', '[0     ]')
# error:  0.00025490
# ('out:    ', '[1.226 ]')
# ('correct:', '[1     ]')
# error:  0.02547125
# ('out:    ', '[1.231 ]')
# ('correct:', '[1     ]')
# error:  0.02658648
# ('out:    ', '[1.318 ]')
# ('correct:', '[1     ]')
# error:  0.05042136
# ('out:    ', '[1.046 ]')
# ('correct:', '[1     ]')
# error:  0.00108041
# ('out:    ', '[1.186 ]')
# ('correct:', '[1     ]')
# error:  0.01734386
# ('out:    ', '[1.375 ]')
# ('correct:', '[1     ]')
# error:  0.07049180
# ('out:    ', '[1.31  ]')
# ('correct:', '[1     ]')
# error:  0.04800165
# ('out:    ', '[1.015 ]')
# ('correct:', '[1     ]')
# error:  0.00011908
# ('out:    ', '[0.763 ]')
# ('correct:', '[1     ]')
# error:  0.02798835
# ('out:    ', '[1.226 ]')
# ('correct:', '[1     ]')
# error:  0.02555219
# ('out:    ', '[1.038 ]')
# ('correct:', '[1     ]')
# error:  0.00070648
# ('out:    ', '[1.126 ]')
# ('correct:', '[1     ]')
# error:  0.00788566
# ('out:    ', '[1.058 ]')
# ('correct:', '[1     ]')
# error:  0.00166079
# ('out:    ', '[0.549 ]')
# ('correct:', '[1     ]')
# error:  0.10149375
# ('out:    ', '[1.092 ]')
# ('correct:', '[1     ]')
# error:  0.00420821
# ('out:    ', '[2.038 ]')
# ('correct:', '[2     ]')
# error:  0.00071104
# ('out:    ', '[2.016 ]')
# ('correct:', '[2     ]')
# error:  0.00013268
# ('out:    ', '[1.877 ]')
# ('correct:', '[2     ]')
# error:  0.00751086
# ('out:    ', '[1.645 ]')
# ('correct:', '[2     ]')
# error:  0.06313816
# ('out:    ', '[1.846 ]')
# ('correct:', '[2     ]')
# error:  0.01179217
# ('out:    ', '[2.016 ]')
# ('correct:', '[2     ]')
# error:  0.00012570
# ('out:    ', '[1.778 ]')
# ('correct:', '[2     ]')
# error:  0.02453625
# ('out:    ', '[1.921 ]')
# ('correct:', '[2     ]')
# error:  0.00310707
# ('out:    ', '[2.05  ]')
# ('correct:', '[2     ]')
# error:  0.00123694
# ('out:    ', '[2.034 ]')
# ('correct:', '[2     ]')
# error:  0.00057254
# ('out:    ', '[1.878 ]')
# ('correct:', '[2     ]')
# error:  0.00747320
# ('out:    ', '[1.847 ]')
# ('correct:', '[2     ]')
# error:  0.01175039
# ('out:    ', '[1.819 ]')
# ('correct:', '[2     ]')
# error:  0.01639054
# ('out:    ', '[1.946 ]')
# ('correct:', '[2     ]')
# error:  0.00144478
# ('out:    ', '[1.814 ]')
# ('correct:', '[2     ]')
# error:  0.01726072
# ('All errors:', [0.0001627678844877047, 7.1683148756703961e-05, 0.00041727944074198387, 0.00058791619216562669, 0.00026160753533093888, 0.00017190045197388877, 0.0017117273979634264, 0.00043934500908830813, 0.00077004719949536244, 0.00068673523969352539, 0.00061467712626295148, 0.00018937570814785804, 0.00046668461995844724, 0.00012761245426865292, 0.00025490324780143579, 0.025471246191256739, 0.026586477453379897, 0.05042135869004194, 0.0010804117472764333, 0.017343861509775946, 0.070491799111435272, 0.048001645438722089, 0.00011908351373155053, 0.027988354220167249, 0.025552186043373445, 0.00070647973311597178, 0.0078856585569976895, 0.0016607901148790146, 0.10149374692412237, 0.0042082140482655158, 0.0007110426680539217, 0.00013267623724480076, 0.0075108645937259988, 0.063138164405711364, 0.011792174711804533, 0.00012569826837281959, 0.024536249387337415, 0.0031070708663733983, 0.0012369416851166814, 0.00057253792691418204, 0.0074731972302920302, 0.011750388314815598, 0.01639053996526614, 0.0014447753583753569, 0.01726071512245585])
# ('Average error:', 0.01295841361543418)
# ('Max error:', 0.10149374692412237, 'Median error:', 0.0014447753583753569)
# 0.01295841361543418

# %%
# construindo a rede
rede = buildNetwork(treinamento.indim, 2, treinamento.outdim, bias=True)
trainer = BackpropTrainer(rede, treinamento, learningrate=0.005, momentum=0.5)

# treinando a rede
for epoca in range(2000):
    trainer.train()
    
# testando a rede
teste = SupervisedDataSet(4, 1)
for i in range(len(entradas_teste)):
    teste.addSample(entradas_teste[i], saidas_teste[i])
trainer.testOnData(teste, verbose=True)
# Out:
# Testing on data:
# ('out:    ', '[0.002 ]')
# ('correct:', '[0     ]')
# error:  0.00000146
# ('out:    ', '[-0.011]')
# ('correct:', '[0     ]')
# error:  0.00005868
# ('out:    ', '[0.009 ]')
# ('correct:', '[0     ]')
# error:  0.00004474
# ('out:    ', '[0.031 ]')
# ('correct:', '[0     ]')
# error:  0.00046851
# ('out:    ', '[0.02  ]')
# ('correct:', '[0     ]')
# error:  0.00020176
# ('out:    ', '[0.025 ]')
# ('correct:', '[0     ]')
# error:  0.00030072
# ('out:    ', '[0.123 ]')
# ('correct:', '[0     ]')
# error:  0.00760076
# ('out:    ', '[0.016 ]')
# ('correct:', '[0     ]')
# error:  0.00012982
# ('out:    ', '[0.179 ]')
# ('correct:', '[0     ]')
# error:  0.01604976
# ('out:    ', '[0.111 ]')
# ('correct:', '[0     ]')
# error:  0.00613965
# ('out:    ', '[0.076 ]')
# ('correct:', '[0     ]')
# error:  0.00288381
# ('out:    ', '[0.003 ]')
# ('correct:', '[0     ]')
# error:  0.00000416
# ('out:    ', '[0.026 ]')
# ('correct:', '[0     ]')
# error:  0.00034350
# ('out:    ', '[-0.002]')
# ('correct:', '[0     ]')
# error:  0.00000223
# ('out:    ', '[0.017 ]')
# ('correct:', '[0     ]')
# error:  0.00013839
# ('out:    ', '[1.084 ]')
# ('correct:', '[1     ]')
# error:  0.00351112
# ('out:    ', '[1.106 ]')
# ('correct:', '[1     ]')
# error:  0.00564062
# ('out:    ', '[1.275 ]')
# ('correct:', '[1     ]')
# error:  0.03769208
# ('out:    ', '[0.973 ]')
# ('correct:', '[1     ]')
# error:  0.00036054
# ('out:    ', '[1.116 ]')
# ('correct:', '[1     ]')
# error:  0.00676260
# ('out:    ', '[1.246 ]')
# ('correct:', '[1     ]')
# error:  0.03014556
# ('out:    ', '[1.143 ]')
# ('correct:', '[1     ]')
# error:  0.01029492
# ('out:    ', '[0.976 ]')
# ('correct:', '[1     ]')
# error:  0.00028689
# ('out:    ', '[0.805 ]')
# ('correct:', '[1     ]')
# error:  0.01909243
# ('out:    ', '[1.111 ]')
# ('correct:', '[1     ]')
# error:  0.00613680
# ('out:    ', '[0.947 ]')
# ('correct:', '[1     ]')
# error:  0.00140555
# ('out:    ', '[1.021 ]')
# ('correct:', '[1     ]')
# error:  0.00022248
# ('out:    ', '[1     ]')
# ('correct:', '[1     ]')
# error:  0.00000002
# ('out:    ', '[0.751 ]')
# ('correct:', '[1     ]')
# error:  0.03105931
# ('out:    ', '[1.015 ]')
# ('correct:', '[1     ]')
# error:  0.00011401
# ('out:    ', '[2.058 ]')
# ('correct:', '[2     ]')
# error:  0.00169497
# ('out:    ', '[2.02  ]')
# ('correct:', '[2     ]')
# error:  0.00020896
# ('out:    ', '[1.853 ]')
# ('correct:', '[2     ]')
# error:  0.01085394
# ('out:    ', '[1.56  ]')
# ('correct:', '[2     ]')
# error:  0.09676207
# ('out:    ', '[1.826 ]')
# ('correct:', '[2     ]')
# error:  0.01521855
# ('out:    ', '[2.044 ]')
# ('correct:', '[2     ]')
# error:  0.00095744
# ('out:    ', '[1.741 ]')
# ('correct:', '[2     ]')
# error:  0.03344248
# ('out:    ', '[1.973 ]')
# ('correct:', '[2     ]')
# error:  0.00037531
# ('out:    ', '[2.058 ]')
# ('correct:', '[2     ]')
# error:  0.00167415
# ('out:    ', '[2.048 ]')
# ('correct:', '[2     ]')
# error:  0.00113230
# ('out:    ', '[1.907 ]')
# ('correct:', '[2     ]')
# error:  0.00432224
# ('out:    ', '[1.929 ]')
# ('correct:', '[2     ]')
# error:  0.00251088
# ('out:    ', '[1.812 ]')
# ('correct:', '[2     ]')
# error:  0.01769126
# ('out:    ', '[1.935 ]')
# ('correct:', '[2     ]')
# error:  0.00212396
# ('out:    ', '[1.799 ]')
# ('correct:', '[2     ]')
# error:  0.02025410
# ('All errors:', [1.4591719303563935e-06, 5.8680702477897467e-05, 4.473593366168655e-05, 0.00046850810590824541, 0.00020176455813756769, 0.00030072327766824888, 0.0076007595914832811, 0.00012981741767501047, 0.016049761425112018, 0.0061396459423386403, 0.0028838125071502514, 4.1568090688575811e-06, 0.00034350219419375144, 2.229894170185232e-06, 0.00013839365583436452, 0.0035111170581804776, 0.0056406166926478811, 0.037692083810442333, 0.00036054406970609964, 0.0067626026887774313, 0.030145556534183097, 0.010294924172895955, 0.00028689464615886886, 0.019092433870383878, 0.0061367960613597297, 0.001405546363135705, 0.00022247559487763888, 1.8275379383698343e-08, 0.031059314332140125, 0.00011400642146627888, 0.0016949672372989413, 0.0002089550504886935, 0.010853944031803949, 0.096762067068329377, 0.015218548076162674, 0.00095743897075626651, 0.033442481483006742, 0.00037530963385914263, 0.0016741473518147886, 0.0011322969325453448, 0.0043222439245647511, 0.0025108771165528779, 0.017691261926650579, 0.0021239607120952077, 0.020254099312560118])
# ('Average error:', 0.0088070106801563276)
# ('Max error:', 0.096762067068329377, 'Median error:', 0.0016949672372989413)
# 0.0088070106801563276

# %%
# construindo a rede
rede = buildNetwork(treinamento.indim, 2, treinamento.outdim, bias=True)
trainer = BackpropTrainer(rede, treinamento, learningrate=0.01, momentum=0.7)

# treinando a rede
for epoca in range(1000):
    trainer.train()
    
# testando a rede
teste = SupervisedDataSet(4, 1)
for i in range(len(entradas_teste)):
    teste.addSample(entradas_teste[i], saidas_teste[i])
trainer.testOnData(teste, verbose=True)
# Out:
# Testing on data:
# ('out:    ', '[0.014 ]')
# ('correct:', '[0     ]')
# error:  0.00009121
# ('out:    ', '[0.001 ]')
# ('correct:', '[0     ]')
# error:  0.00000078
# ('out:    ', '[0.023 ]')
# ('correct:', '[0     ]')
# error:  0.00026014
# ('out:    ', '[0.005 ]')
# ('correct:', '[0     ]')
# error:  0.00001415
# ('out:    ', '[-0.006]')
# ('correct:', '[0     ]')
# error:  0.00001666
# ('out:    ', '[-0.02 ]')
# ('correct:', '[0     ]')
# error:  0.00020363
# ('out:    ', '[0.334 ]')
# ('correct:', '[0     ]')
# error:  0.05587620
# ('out:    ', '[-0.021]')
# ('correct:', '[0     ]')
# error:  0.00021614
# ('out:    ', '[0.003 ]')
# ('correct:', '[0     ]')
# error:  0.00000407
# ('out:    ', '[-0.032]')
# ('correct:', '[0     ]')
# error:  0.00050258
# ('out:    ', '[0.057 ]')
# ('correct:', '[0     ]')
# error:  0.00162375
# ('out:    ', '[-0.04 ]')
# ('correct:', '[0     ]')
# error:  0.00078372
# ('out:    ', '[-0.01 ]')
# ('correct:', '[0     ]')
# error:  0.00004558
# ('out:    ', '[-0.029]')
# ('correct:', '[0     ]')
# error:  0.00040706
# ('out:    ', '[0.001 ]')
# ('correct:', '[0     ]')
# error:  0.00000027
# ('out:    ', '[0.843 ]')
# ('correct:', '[1     ]')
# error:  0.01234573
# ('out:    ', '[1.015 ]')
# ('correct:', '[1     ]')
# error:  0.00011251
# ('out:    ', '[1.11  ]')
# ('correct:', '[1     ]')
# error:  0.00610156
# ('out:    ', '[0.807 ]')
# ('correct:', '[1     ]')
# error:  0.01863175
# ('out:    ', '[1.038 ]')
# ('correct:', '[1     ]')
# error:  0.00072240
# ('out:    ', '[1.115 ]')
# ('correct:', '[1     ]')
# error:  0.00666591
# ('out:    ', '[1.021 ]')
# ('correct:', '[1     ]')
# error:  0.00022658
# ('out:    ', '[0.965 ]')
# ('correct:', '[1     ]')
# error:  0.00060192
# ('out:    ', '[0.873 ]')
# ('correct:', '[1     ]')
# error:  0.00809584
# ('out:    ', '[1.01  ]')
# ('correct:', '[1     ]')
# error:  0.00004577
# ('out:    ', '[0.802 ]')
# ('correct:', '[1     ]')
# error:  0.01963064
# ('out:    ', '[0.903 ]')
# ('correct:', '[1     ]')
# error:  0.00472264
# ('out:    ', '[0.952 ]')
# ('correct:', '[1     ]')
# error:  0.00113510
# ('out:    ', '[0.793 ]')
# ('correct:', '[1     ]')
# error:  0.02148723
# ('out:    ', '[0.93  ]')
# ('correct:', '[1     ]')
# error:  0.00244211
# ('out:    ', '[1.996 ]')
# ('correct:', '[2     ]')
# error:  0.00000759
# ('out:    ', '[1.973 ]')
# ('correct:', '[2     ]')
# error:  0.00036103
# ('out:    ', '[1.839 ]')
# ('correct:', '[2     ]')
# error:  0.01290354
# ('out:    ', '[1.545 ]')
# ('correct:', '[2     ]')
# error:  0.10340930
# ('out:    ', '[1.815 ]')
# ('correct:', '[2     ]')
# error:  0.01708276
# ('out:    ', '[2.01  ]')
# ('correct:', '[2     ]')
# error:  0.00005488
# ('out:    ', '[1.761 ]')
# ('correct:', '[2     ]')
# error:  0.02862328
# ('out:    ', '[1.956 ]')
# ('correct:', '[2     ]')
# error:  0.00095855
# ('out:    ', '[2.014 ]')
# ('correct:', '[2     ]')
# error:  0.00009151
# ('out:    ', '[2.011 ]')
# ('correct:', '[2     ]')
# error:  0.00005513
# ('out:    ', '[1.914 ]')
# ('correct:', '[2     ]')
# error:  0.00368973
# ('out:    ', '[1.876 ]')
# ('correct:', '[2     ]')
# error:  0.00764377
# ('out:    ', '[1.809 ]')
# ('correct:', '[2     ]')
# error:  0.01822770
# ('out:    ', '[1.925 ]')
# ('correct:', '[2     ]')
# error:  0.00278234
# ('out:    ', '[1.799 ]')
# ('correct:', '[2     ]')
# error:  0.02029062
# ('All errors:', [9.1212192365349609e-05, 7.7552102257862615e-07, 0.00026014421408198903, 1.4154735165341235e-05, 1.6660085818701093e-05, 0.00020363371539664155, 0.055876199752904261, 0.00021614242285191134, 4.0682513487679402e-06, 0.00050258026602230106, 0.0016237527376425738, 0.00078372171381169695, 4.5580298969912047e-05, 0.00040706025883009342, 2.668453853510766e-07, 0.012345733583808211, 0.00011250710479348179, 0.0061015568020194675, 0.018631750391275778, 0.00072240067357536768, 0.0066659110978477126, 0.00022658486457473117, 0.00060191687310484762, 0.0080958382593105307, 4.577119531694152e-05, 0.019630643109532171, 0.0047226378775034423, 0.0011351007413177852, 0.021487229942141011, 0.002442110293852804, 7.5912972507089789e-06, 0.00036103374189232451, 0.012903542835308857, 0.10340930014088417, 0.017082762124293105, 5.4884126108123393e-05, 0.02862328421216933, 0.00095854625086037599, 9.1510416231989545e-05, 5.5132930691231554e-05, 0.0036897303485161608, 0.0076437741126942332, 0.018227701649013113, 0.0027823390367402441, 0.020290617835897588])
# ('Average error:', 0.0084265643751142948)
# ('Max error:', 0.10340930014088417, 'Median error:', 0.00078372171381169695)
# 0.0084265643751142948
